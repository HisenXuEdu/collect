# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

csv_file = "../Data/pose/POSE1700831933598.csv"
# csv_data = pd.read_csv(csv_file, low_memory = False)#防止弹出警告
csv_data = pd.read_csv(csv_file)#防止弹出警告
csv_df = pd.DataFrame(csv_data)
print(csv_df.shape)
# csv_df = csv_df.stack().unstack(0)
# scaler = StandardScaler(with_mean=True,
#                             with_std=True,
#                             copy=False).fit(csv_df.iloc[:, :])

# scaled = scaler.transform(csv_df.iloc[:,:])
# csv_df = pd.DataFrame(scaled)
# x_df = csv_df.iloc[:,[6]]
# x_df[:].plot(figsize = (15,2),color='orange')
x = csv_df.iloc[:,[0]]
plot = x[:].plot(figsize = (15,2), legend=False,color='blue')
plot.legend(['x'])  # 自定义图例标签
plt.title('POSE')
y = csv_df.iloc[:,[1]]
plot = y[:].plot(figsize = (15,2), legend=False,color='orange')
plot.legend(['y'])  # 自定义图例标签
plt.title('POSE')
# x_df = csv_df.iloc[:,[0]]
# x_df[:].plot(figsize = (15,2),color='orange',legend=False)
# plot.legend(['x'])
# y_df = csv_df.iloc[:,[1]]
# y_df[:].plot(figsize = (15,2),color='blue')
# z_df = csv_df.iloc[:,[2]]
# z_df[:].plot(figsize = (15,2),color='green')
# Out:
# (7338, 7)
# Text(0.5, 1.0, 'POSE')
