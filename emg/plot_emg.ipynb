# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

path ="../Data/emg/"
file_name = "EMG1700831936722.csv"
csv_file = path + file_name
# csv_data = pd.read_csv(csv_file, low_memory = False)#防止弹出警告
csv_data = pd.read_csv(csv_file)#防止弹出警告
csv_df = pd.DataFrame(csv_data)
print(csv_df.shape)
csv_df = csv_df.T
# csv_df = csv_df.stack().unstack(0)
# scaler = StandardScaler(with_mean=True,
#                             with_std=True,
#                             copy=False).fit(csv_df.iloc[:, :])

# scaled = scaler.transform(csv_df.iloc[:,:])
# csv_df = pd.DataFrame(scaled)
# csv_df.to_csv('../Data/emg/emgresize/'+file_name, index=None)
csv_df = csv_df.iloc[:,[1,2,3,4,5,6]]
plot = csv_df[:].plot(figsize = (15,5), legend=False)
plot.legend(['emg1', 'emg2', 'emg3', 'emg4', 'emg5', 'emg6'])  # 自定义图例标签
plt.title('EMG')
# Out:
# (7, 120000)
# Text(0.5, 1.0, 'EMG')
