# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

csv_file = "../Data/force/FORCE1700832156440.csv"
# csv_data = pd.read_csv(csv_file, low_memory = False)#防止弹出警告
csv_data = pd.read_csv(csv_file)#防止弹出警告
csv_df = pd.DataFrame(csv_data)
print(csv_df.shape)
# csv_df = csv_df.stack().unstack(0)
# scaler = StandardScaler(with_mean=True,
#                             with_std=True,
#                             copy=False).fit(csv_df.iloc[:, :])

# scaled = scaler.transform(csv_df.iloc[:,:])
# csv_df = pd.DataFrame(scaled)
# csv_df = csv_df.iloc[:,[3,4,5,6,7,8]]
csv_df = csv_df.iloc[:,[4,3]]
plot = csv_df[:].plot(figsize = (15,5), legend=False)
plot = csv_df[1500:4500].plot(figsize = (15,3), legend=False)
# plot.legend(['x', 'y', 'z', 'r', 'p', 'y'])  # 自定义图例标签
plot.legend(['x', 'y'])  # 自定义图例标签
plt.ylim(-25, 25) 
plt.title('FORCE')
# Out:
# (6000, 10)
# Text(0.5, 1.0, 'FORCE')
